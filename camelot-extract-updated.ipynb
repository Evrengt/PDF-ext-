# %%
import camelot
import os
import ctypes

# %%
#os.chdir('C:\\Users\\WIN10\\Desktop\\TASKS\\siftah')
#tables2=camelot.read_pdf('YLB.pdf', flavor='stream', pages='0-8')
#tables2
# Out:
# <TableList n=16>

# %%
tables = camelot.read_pdf('YLB MAYIS.pdf', flavor='stream', pages='all')

# %%
type(tables)
# Out:
# camelot.core.TableList

# %%
len(tables)
# Out:
# 12

# %%
tables[0].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 0.76, 'order': 1, 'page': 0}

# %%
tables2[2].parsing_report
# Out:
# {'accuracy': 99.89, 'whitespace': 47.97, 'order': 1, 'page': 1}

# %%
df2=tables2[2].df
df2
# Out:
#                                                     0  1  \
# 0                                 B. KURUCUNUN UNVANI  :
# 1   C. YÖNETİCİNİN UNVANI                         ...
# 2                             Ç. TOPLAM DEĞER/NET \n:
# 3                                       VARLIK DEĞERİ
# 4                         :\n  D. KATILMA PAYI SAYISI
# 5                        :\n  E. FONUN KURULUŞ TARİHİ
# 6                                :\n  F. FONUN SÜRESİ
# 7                             II- FONUN PERFORMANSINA
# 8                                    İLİŞKİN BİLGİLER
# 9                         A. AY SONU KATILMA PAYI \n:
# 10                                             FİYATI
# 11                           B. ÖNCEKİ AY KATILMA \n:
# 12                                        PAYI FİYATI
# 13                          C. AYLIK KATILMA PAYI \n:
# 14                                 FİYATI ARTIŞ ORANI
# 15                        Ç. YILBAŞINA GÖRE FİYAT \n:
# ...

# %%
tables2[3]
tables2[3].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 0.0, 'order': 1, 'page': 2}

# %%
df3=tables2[3].df
df3
# Out:
#                0             1           2                   3  \
# 0   TRFAKFK82217  TRFAKFK82217  26.08.2022          AKFINANSAL
# 1   TRFDNFK62217  TRFDNFK62217  10.06.2022         DENIZFINANS
# 2   TRFDZBK62236  TRFDZBK62236  01.06.2022           DENIZBANK
# 3   TRFDZBK62244  TRFDZBK62244  17.06.2022           DENIZBANK
# 4   TRFDZBK82226  TRFDZBK82226  03.08.2022           DENIZBANK
# 5   TRFDZBK92217  TRFDZBK92217  09.09.2022           DENIZBANK
# 6   TRFDZFK62211  TRFDZFK62211  08.06.2022      DENIZFAKTORING
# 7   TRFDZFK72210  TRFDZFK72210  29.07.2022      DENIZFAKTORING
# 8   TRFFNBK52253  TRFFNBK52253  20.05.2022          FINANSBANK
# 9   TRFFNBK62211  TRFFNBK62211  10.06.2022          FINANSBANK
# 10  TRFFNBK62237  TRFFNBK62237  03.06.2022          FINANSBANK
# 11  TRFFNBK62245  TRFFNBK62245  03.06.2022          FINANSBANK
# 12  TRFFNBK62252  TRFFNBK62252  10.06.2022          FINANSBANK
# 13  TRFFNBK62260  TRFFNBK62260  17.06.2022          FINANSBANK
# ...

# %%
tables2[5]
tables2[5].parsing_report
# Out:
# {'accuracy': 99.86, 'whitespace': 38.32, 'order': 1, 'page': 3}

# %%
df5=tables2[5].df
df5
# Out:
#                         0  1             2           3  \
# 0            TRFYKBK62242     TRFYKBK62242  27.06.2022
# 1            TRFYKBK72225     TRFYKBK72225  29.07.2022
# 2            TRFYKBK72233     TRFYKBK72233  22.07.2022
# 3            TRFYKBK82216     TRFYKBK82216  05.08.2022
# 4            TRFYKYM62216     TRFYKYM62216  15.06.2022
# 5                  TOPLAM
# 6          F) ÖZEL SEKTÖR  :
# 7              TAHVİLLERİ
# 8            TRSARCL42313     TRSARCL42313  27.04.2023
# 9            TRSARCL42412     TRSARCL42412  05.04.2024
# 10           TRSYKBKE2219     TRSYKBKE2219  14.10.2022
# 11                 TOPLAM
# 12           N) TERS REPO  :
# 13           TRT171127T15     TRT171127T15  05.05.2022
# 14           TRT171127T15     TRT171127T15  05.05.2022
# 15                 TOPLAM
# 16      O) TAKASBANK PARA  :
# 17               PİYASASI
# 18                    BPP                   06.05.2022
# 19                    BPP                   10.05.2022
# ...

# %%
tables2[7]
tables2[7].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 25.71, 'order': 1, 'page': 4}

# %%
df7=tables2[7].df
df7
# Out:
#                          0  1           2                         3  \
# 0    Vadeli Mevduat gün 42     10.05.2022                 Odea Bank
# 1    Vadeli Mevduat gün 47     10.05.2022         TC Ziraat Bankası
# 2    Vadeli Mevduat gün 47     10.05.2022      Türk Ekonomi Bankası
# 3    Vadeli Mevduat gün 47     10.05.2022  Türkiye Vakıflar Bankası
# 4    Vadeli Mevduat gün 58     23.06.2022     Yapı ve Kredi Bankası
# 5    Vadeli Mevduat gün 58     23.06.2022  Türkiye Vakıflar Bankası
# 6    Vadeli Mevduat gün 58     23.06.2022      Türkiye Halk Bankası
# 7    Vadeli Mevduat gün 58     23.06.2022                    Akbank
# 8    Vadeli Mevduat gün 58     23.06.2022           Deniz Bank A.Ş.
# 9    Vadeli Mevduat gün 58     23.06.2022      Türk Ekonomi Bankası
# 10                  TOPLAM
# 11  P) KATILIM HESABI - TL  :
# 12   Katılım Hesabı gün 36     10.05.2022
# 13   Katılım Hesabı gün 42     10.05.2022
# 14                  TOPLAM
#
#                  4                 5      6
# ...

# %%
tables2[9]
tables2[9].parsing_report
# Out:
# {'accuracy': 99.98, 'whitespace': 53.5, 'order': 1, 'page': 5}

# %%
df9=tables2[9].df
df9
# Out:
#                            0  1              2             3  \
# 0       VI-A-GEÇEN AY İÇİNDE
# 1               RÜÇHAN HAKKI
# 2        KULLANIMI, BEDELSİZ
# 3        HİSSE SENEDİ ALIMI,
# 4         TEMETTÜ VE ANAPARA
# 5                TAHSİLATINA
# 6        İLİŞKİN AÇIKLAMALAR  :
# 7                   Açıklama      Giriş Tarihi          Stok
# 8         B- GEÇEN AY İÇİNDE
# 9          YATIRIM FONLARINA
# 10                   İLİŞKİN
# 11         MEVZUATTA MEYDANA
# 12                     GELEN
# 13         DEĞİŞME VE HUKUKİ
# 14              İHTİLAFLARLA
# 15       İLGİLİ AÇIKLAMALAR:  :
# 16  VII- PORTFÖYDEN SATIŞLAR  :
# 17        Menkul Kıymet Türü     İhraçcı Kurum  Satış Tarihi
# 18   Takasbank Para Piyasası                      01.04.2022
# 19   Takasbank Para Piyasası                      04.04.2022
# 20   Takasbank Para Piyasası                      04.04.2022
# 21   Takasbank Para Piyasası                      04.04.2022
# ...

# %%
tables2[11]
tables2[11].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 19.84, 'order': 2, 'page': 6}

# %%
df11=tables2[11].df
df11
# Out:
#                            0                   1            2  \
# 0    Takasbank Para Piyasası                       18.04.2022
# 1    Takasbank Para Piyasası                       20.04.2022
# 2    Takasbank Para Piyasası                       21.04.2022
# 3    Takasbank Para Piyasası                       22.04.2022
# 4    Takasbank Para Piyasası                       22.04.2022
# 5    Takasbank Para Piyasası                       22.04.2022
# 6    Takasbank Para Piyasası                       22.04.2022
# 7    Takasbank Para Piyasası                       22.04.2022
# 8    Takasbank Para Piyasası                       25.04.2022
# 9    Takasbank Para Piyasası                       26.04.2022
# 10   Takasbank Para Piyasası                       26.04.2022
# 11   Takasbank Para Piyasası                       26.04.2022
# 12   Takasbank Para Piyasası                       26.04.2022
# 13   Takasbank Para Piyasası                       27.04.2022
# ...

# %%
tables2[13]
tables2[13].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 0.0, 'order': 1, 'page': 7}

# %%
df13=tables2[13].df
df13
# Out:
#                            0             1           2           3  \
# 0   Devlet Tahvili Ters Repo  TRT261022T10  07.04.2022  08.04.2022
# 1   Devlet Tahvili Ters Repo  TRT261022T10  07.04.2022  08.04.2022
# 2   Devlet Tahvili Ters Repo  TRT110827T16  08.04.2022  11.04.2022
# 3   Devlet Tahvili Ters Repo  TRT140126T11  08.04.2022  11.04.2022
# 4   Devlet Tahvili Ters Repo  TRT140126T11  08.04.2022  11.04.2022
# 5   Devlet Tahvili Ters Repo  TRT140623T19  08.04.2022  11.04.2022
# 6   Devlet Tahvili Ters Repo  TRT171127T15  08.04.2022  11.04.2022
# 7   Devlet Tahvili Ters Repo  TRT020823T11  11.04.2022  12.04.2022
# 8   Devlet Tahvili Ters Repo  TRT100124T17  11.04.2022  12.04.2022
# 9   Devlet Tahvili Ters Repo  TRT140126T11  11.04.2022  12.04.2022
# 10  Devlet Tahvili Ters Repo  TRT171127T15  11.04.2022  12.04.2022
# 11  Devlet Tahvili Ters Repo  TRT180625T13  11.04.2022  12.04.2022
# 12  Devlet Tahvili Ters Repo  TRT180625T13  11.04.2022  12.04.2022
# ...

# %%
tables2[15]
tables2[15].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 1.19, 'order': 2, 'page': 8}

# %%
df15=tables2[15].df
df15
# Out:
#                            0             1           2           3  \
# 0   Devlet Tahvili Ters Repo  TRT020823T11  18.04.2022  19.04.2022
# 1   Devlet Tahvili Ters Repo  TRT140623T19  18.04.2022  19.04.2022
# 2   Devlet Tahvili Ters Repo  TRT171127T15  18.04.2022  19.04.2022
# 3   Devlet Tahvili Ters Repo  TRT171127T15  18.04.2022  19.04.2022
# 4   Devlet Tahvili Ters Repo  TRT171127T15  19.04.2022  20.04.2022
# 5   Devlet Tahvili Ters Repo  TRT171127T15  19.04.2022  20.04.2022
# 6   Devlet Tahvili Ters Repo  TRT171127T15  20.04.2022  21.04.2022
# 7   Devlet Tahvili Ters Repo  TRT171127T15  20.04.2022  21.04.2022
# 8   Devlet Tahvili Ters Repo  TRT171127T15  21.04.2022  22.04.2022
# 9   Devlet Tahvili Ters Repo  TRT171127T15  21.04.2022  22.04.2022
# 10  Devlet Tahvili Ters Repo  TRT140126T11  22.04.2022  25.04.2022
# 11  Devlet Tahvili Ters Repo  TRT171127T15  22.04.2022  25.04.2022
# 12  Devlet Tahvili Ters Repo  TRT171127T15  22.04.2022  25.04.2022
# ...

# %%
## TableList içindeki objeleri -> "page"'e göre sort
## sort edilmiş DF'ler olacak elimizde
# {'accuracy': 100.0, 'whitespace': 0.0, 'order': 1, 'page': 0}
# {'accuracy': 100.0, 'whitespace': 0.0, 'order': 1, 'page': 1}
# {'accuracy': 100.0, 'whitespace': 0.0, 'order': 1, 'page': 2}

# %%
tables[0].parsing_report
# Out:
# {'accuracy': 99.89, 'whitespace': 47.97, 'order': 1, 'page': 1}

# %%
tables[1].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 0.0, 'order': 1, 'page': 2}

# %%
tables[2].parsing_report
# Out:
# {'accuracy': 99.85, 'whitespace': 36.41, 'order': 1, 'page': 3}

# %%
for table in tables:
    print(table.parsing_report)
# Out:
# {'accuracy': 99.89, 'whitespace': 47.97, 'order': 1, 'page': 1}
# {'accuracy': 100.0, 'whitespace': 0.0, 'order': 1, 'page': 2}
# {'accuracy': 99.85, 'whitespace': 36.41, 'order': 1, 'page': 3}
# {'accuracy': 99.85, 'whitespace': 36.41, 'order': 2, 'page': 3}
# {'accuracy': 100.0, 'whitespace': 70.23, 'order': 1, 'page': 4}
# {'accuracy': 99.98, 'whitespace': 29.56, 'order': 1, 'page': 5}
# {'accuracy': 99.98, 'whitespace': 61.11, 'order': 2, 'page': 5}
# {'accuracy': 100.0, 'whitespace': 33.81, 'order': 1, 'page': 6}
# {'accuracy': 100.0, 'whitespace': 0.76, 'order': 1, 'page': 7}
# {'accuracy': 100.0, 'whitespace': 0.76, 'order': 2, 'page': 7}

# %%
## TODO:

# her sayfadaki DF'leri
# TEK BİR MEGA_DF'de birleştirelim ? 
# df1, df2, df3 ---> DF( df1 + df2 + df3 )
