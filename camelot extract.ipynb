# %%
import camelot
import os
import ctypes

# %%
os.chdir('C:\\Users\\WIN10\\Desktop\\TASKS\\siftah')
tables2=camelot.read_pdf('YLB.pdf', flavor='stream', pages='0-8')
tables2
# Out:
# <TableList n=16>

# %%
tables2[2]
# Out:
# <Table shape=(41, 3)>

# %%
tables2[2].parsing_report
# Out:
# {'accuracy': 99.89, 'whitespace': 47.97, 'order': 1, 'page': 1}

# %%
df2=tables2[2].df
df2
# Out:
#                                                     0  1  \
# 0                                 B. KURUCUNUN UNVANI  :
# 1   C. YÖNETİCİNİN UNVANI                         ...
# 2                             Ç. TOPLAM DEĞER/NET \n:
# 3                                       VARLIK DEĞERİ
# 4                         :\n  D. KATILMA PAYI SAYISI
# 5                        :\n  E. FONUN KURULUŞ TARİHİ
# 6                                :\n  F. FONUN SÜRESİ
# 7                             II- FONUN PERFORMANSINA
# 8                                    İLİŞKİN BİLGİLER
# 9                         A. AY SONU KATILMA PAYI \n:
# 10                                             FİYATI
# 11                           B. ÖNCEKİ AY KATILMA \n:
# 12                                        PAYI FİYATI
# 13                          C. AYLIK KATILMA PAYI \n:
# 14                                 FİYATI ARTIŞ ORANI
# 15                        Ç. YILBAŞINA GÖRE FİYAT \n:
# 16                                        ARTIŞ ORANI
# 17                         D. YILLIK KATILMA PAYI \n:
# 18                                 FİYATI ARTIŞ ORANI
# 19                                  E. AYLIK ORTALAMA
# 20                                        PORTFÖYDEKİ
# 21                               MENKUL KIYMETLER \n:
# 22                                            YÜZDESİ
# 23                                Özel Sektör Tahvili
# 24                           Devlet Tahvili Ters Repo
# 25                            Takasbank Para Piyasası
# 26                                     Vadeli Mevduat
# 27                                     Katılım Hesabı
# 28                                               VDMK
# 29                              F. AYLIK ORTALAMA \n:
# 30                                 PORTFÖY DEVİR HIZI
# 31                          G. PORTFÖYÜN ORTALAMA \n:
# 32                                             VADESİ
# 33                                Ğ. KATILMA PAYI \n:
# 34                                      İHRAÇLARINDAN
# 35                                  KAYNAKLANAN NAKİT
# 36                                          GİRİŞLERİ
# 37                                H. KATILMA PAYI \n:
# 38                                       İADELERİNDEN
# 39                                  KAYNAKLANAN NAKİT
# 40                                          ÇIKIŞLARI
#
#                                    2
# 0   YAPI KREDİ PORTFÖY YÖNETİMİ A.Ş.
# 1   YAPI KREDİ PORTFÖY YÖNETİMİ A.Ş.
# 2                   5,233,487,628.81
# 3
# 4                  13,217,388,747.00
# 5                         29.06.2000
# 6                            Süresiz
# 7                                 TL
# 8
# 9                           0.395955
# 10
# 11                          0.390243
# 12
# 13                             1.46%
# 14
# 15                             5.33%
# 16
# 17                            17.60%
# 18
# 19
# 20
# 21
# 22
# 23                            36.95%
# 24                             7.27%
# 25                            17.20%
# 26                            34.00%
# 27                             4.53%
# 28                             0.05%
# 29                            11.08%
# 30
# 31                            31.365
# 32
# 33                  9,989,996,330.74
# 34
# 35
# 36
# 37                 10,217,304,968.60
# 38
# 39
# 40

# %%
tables2[3]
tables2[3].parsing_report
# Out:
# {'accuracy': 100.0, 'whitespace': 0.0, 'order': 1, 'page': 2}

# %%
df3=tables2[3].df
df3
# Out:
#                0             1           2                   3  \
# 0   TRFAKFK82217  TRFAKFK82217  26.08.2022          AKFINANSAL
# 1   TRFDNFK62217  TRFDNFK62217  10.06.2022         DENIZFINANS
# 2   TRFDZBK62236  TRFDZBK62236  01.06.2022           DENIZBANK
# 3   TRFDZBK62244  TRFDZBK62244  17.06.2022           DENIZBANK
# 4   TRFDZBK82226  TRFDZBK82226  03.08.2022           DENIZBANK
# 5   TRFDZBK92217  TRFDZBK92217  09.09.2022           DENIZBANK
# 6   TRFDZFK62211  TRFDZFK62211  08.06.2022      DENIZFAKTORING
# 7   TRFDZFK72210  TRFDZFK72210  29.07.2022      DENIZFAKTORING
# 8   TRFFNBK52253  TRFFNBK52253  20.05.2022          FINANSBANK
# 9   TRFFNBK62211  TRFFNBK62211  10.06.2022          FINANSBANK
# 10  TRFFNBK62237  TRFFNBK62237  03.06.2022          FINANSBANK
# 11  TRFFNBK62245  TRFFNBK62245  03.06.2022          FINANSBANK
# 12  TRFFNBK62252  TRFFNBK62252  10.06.2022          FINANSBANK
# 13  TRFFNBK62260  TRFFNBK62260  17.06.2022          FINANSBANK
# 14  TRFFNBK62278  TRFFNBK62278  17.06.2022          FINANSBANK
# 15  TRFGRFA52239  TRFGRFA52239  31.05.2022    GARANTIFAKTORING
# 16  TRFISFA62216  TRFISFA62216  21.06.2022         ISFAKTORING
# 17  TRFISFA72215  TRFISFA72215  01.07.2022         ISFAKTORING
# 18  TRFISFA82214  TRFISFA82214  02.08.2022         ISFAKTORING
# 19  TRFISFN62219  TRFISFN62219  14.06.2022            ISFINANS
# 20  TRFISFN62243  TRFISFN62243  03.06.2022            ISFINANS
# 21  TRFISFN72218  TRFISFN72218  26.07.2022            ISFINANS
# 22  TRFISFN72226  TRFISFN72226  04.07.2022            ISFINANS
# 23  TRFISFN72234  TRFISFN72234  07.07.2022            ISFINANS
# 24  TRFISFN72259  TRFISFN72259  20.07.2022            ISFINANS
# 25  TRFISFN82233  TRFISFN82233  22.08.2022            ISFINANS
# 26  TRFISMD52217  TRFISMD52217  06.05.2022           ISYATIRIM
# 27  TRFISMD52225  TRFISMD52225  06.05.2022           ISYATIRIM
# 28  TRFISMD52233  TRFISMD52233  09.05.2022           ISYATIRIM
# 29  TRFISMD52258  TRFISMD52258  18.05.2022           ISYATIRIM
# 30  TRFISMD52274  TRFISMD52274  27.05.2022           ISYATIRIM
# 31  TRFKCTF72215  TRFKCTF72215  13.07.2022         KOCTUKETICI
# 32  TRFKCTF72223  TRFKCTF72223  07.07.2022         KOCTUKETICI
# 33  TRFKFTF72218  TRFKFTF72218  20.07.2022             KOCFIAT
# 34  TRFTEBK52212  TRFTEBK52212  20.05.2022                 TEB
# 35  TRFTEBK62211  TRFTEBK62211  03.06.2022                 TEB
# 36  TRFTHAL52223  TRFTHAL52223  13.05.2022        THALKBANKASI
# 37  TRFVKFB72221  TRFVKFB72221  22.07.2022           VAKIFBANK
# 38  TRFYAKF62210  TRFYAKF62210  07.06.2022  YAPIKREDIFAKTORING
# 39  TRFYAKF62228  TRFYAKF62228  21.06.2022  YAPIKREDIFAKTORING
# 40  TRFYAKF72219  TRFYAKF72219  06.07.2022  YAPIKREDIFAKTORING
# 41  TRFYKBK52219  TRFYKBK52219  20.05.2022       YAPIKREDIBANK
# 42  TRFYKBK52243  TRFYKBK52243  16.05.2022       YAPIKREDIBANK
# 43  TRFYKBK62226  TRFYKBK62226  10.06.2022       YAPIKREDIBANK
#
#                  4               5     6
# 0     6,500,000.00    6,144,190.00  0.12
# 1     8,000,000.00    7,860,720.00  0.15
# 2    50,000,000.00   49,380,000.00  0.94
# 3    69,600,000.00   68,162,064.00  1.30
# 4    30,000,000.00   28,751,100.00  0.55
# 5    30,000,000.00   28,172,700.00  0.54
# 6    12,000,000.00   11,806,440.00  0.23
# 7    12,750,000.00   12,229,545.00  0.23
# 8    15,000,000.00   14,891,550.00  0.28
# 9    13,000,000.00   13,104,650.00  0.25
# 10   13,400,000.00   13,193,238.00  0.25
# 11   34,600,000.00   34,114,562.00  0.65
# 12   50,000,000.00   49,128,500.00  0.94
# 13   43,000,000.00   42,157,200.00  0.80
# 14   75,000,000.00   73,455,000.00  1.40
# 15   44,600,000.00   44,036,702.00  0.84
# 16   15,000,000.00   14,657,400.00  0.28
# 17   23,200,000.00   22,571,512.00  0.43
# 18   35,000,000.00   33,511,450.00  0.64
# 19   25,000,000.00   24,519,250.00  0.47
# 20   31,870,000.00   31,422,863.90  0.60
# 21   39,100,000.00   37,596,996.00  0.72
# 22   37,600,000.00   36,512,984.00  0.70
# 23   44,000,000.00   42,667,240.00  0.81
# 24   25,930,000.00   24,979,406.20  0.48
# 25   10,090,000.00    9,576,822.60  0.18
# 26   20,000,000.00   19,990,800.00  0.38
# 27   50,000,000.00   49,975,500.00  0.95
# 28   70,000,000.00   69,863,500.00  1.33
# 29   50,000,000.00   49,683,500.00  0.95
# 30   75,000,000.00   74,197,500.00  1.42
# 31    4,600,000.00    5,340,140.00  0.10
# 32    7,000,000.00    7,482,860.00  0.14
# 33   10,000,000.00   10,666,600.00  0.20
# 34  224,000,000.00  222,434,240.00  4.24
# 35  100,000,000.00   98,670,000.00  1.88
# 36   22,000,000.00   21,918,380.00  0.42
# 37   30,120,000.00   29,038,993.20  0.55
# 38    9,000,000.00    8,854,920.00  0.17
# 39    5,500,000.00    5,375,040.00  0.10
# 40    5,000,000.00    4,850,000.00  0.09
# 41   57,000,000.00   57,719,910.00  1.10
# 42   65,000,000.00   64,660,050.00  1.23
# 43   80,000,000.00   78,624,800.00  1.50

# %%
df4=df2.append(df3)
df4
# Out:
# C:\Users\WIN10\AppData\Local\Temp/ipykernel_14912/2907342928.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df4=df2.append(df3)
#                                                     0             1  \
# 0                                 B. KURUCUNUN UNVANI             :
# 1   C. YÖNETİCİNİN UNVANI                         ...
# 2                             Ç. TOPLAM DEĞER/NET \n:
# 3                                       VARLIK DEĞERİ
# 4                         :\n  D. KATILMA PAYI SAYISI
# ..                                                ...           ...
# 39                                       TRFYAKF62228  TRFYAKF62228
# 40                                       TRFYAKF72219  TRFYAKF72219
# 41                                       TRFYKBK52219  TRFYKBK52219
# 42                                       TRFYKBK52243  TRFYKBK52243
# 43                                       TRFYKBK62226  TRFYKBK62226
#
#                                    2                   3              4  \
# 0   YAPI KREDİ PORTFÖY YÖNETİMİ A.Ş.                 NaN            NaN
# 1   YAPI KREDİ PORTFÖY YÖNETİMİ A.Ş.                 NaN            NaN
# 2                   5,233,487,628.81                 NaN            NaN
# 3                                                    NaN            NaN
# 4                  13,217,388,747.00                 NaN            NaN
# ..                               ...                 ...            ...
# 39                        21.06.2022  YAPIKREDIFAKTORING   5,500,000.00
# 40                        06.07.2022  YAPIKREDIFAKTORING   5,000,000.00
# 41                        20.05.2022       YAPIKREDIBANK  57,000,000.00
# 42                        16.05.2022       YAPIKREDIBANK  65,000,000.00
# 43                        10.06.2022       YAPIKREDIBANK  80,000,000.00
#
#                 5     6
# 0             NaN   NaN
# 1             NaN   NaN
# 2             NaN   NaN
# 3             NaN   NaN
# 4             NaN   NaN
# ..            ...   ...
# 39   5,375,040.00  0.10
# 40   4,850,000.00  0.09
# 41  57,719,910.00  1.10
# 42  64,660,050.00  1.23
# 43  78,624,800.00  1.50
#
# [85 rows x 7 columns]
